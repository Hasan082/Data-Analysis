# %% [markdown]
# # Pie Charts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('survey-data.csv')
df.head(5)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# # Visualizing Data Composition with Pie Charts¶
# 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With
# In the survey data, the DatabaseWantToWorkWith column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
df_copied = df[['DatabaseWantToWorkWith']].copy()
df_copied_cleaned = df_copied.dropna(subset=['DatabaseWantToWorkWith'])
df_copied_cleaned.loc[:,'DatabaseWantToWorkWith'] = df_copied_cleaned['DatabaseWantToWorkWith'].str.split(';')
df_copied_cleaned = df_copied_cleaned.explode('DatabaseWantToWorkWith')
df_copied_cleaned_count = df_copied_cleaned.value_counts().reset_index()
df_copied_cleaned_count.columns = ['DatabaseWantToWorkWith', 'Count']
df_copied_cleaned_count = df_copied_cleaned_count.sort_values(by='Count', ascending=False)
top_5_databases = df_copied_cleaned_count.sort_values(by='Count', ascending=False).head(5)

# %%
plt.figure(figsize=(8, 8))
plt.pie(
    top_5_databases['Count'],
    labels=top_5_databases['DatabaseWantToWorkWith'],
    autopct='%1.1f%%',
    startangle=90,    
)
plt.axis('equal')
plt.show()

# %%
df_cleaned_os = df[['OpSysProfessional use']].dropna(subset=['OpSysProfessional use'])
df_cleaned_os['OpSysProfessional use'] = df_cleaned_os['OpSysProfessional use'].str.split(';')
df_cleaned_os_exploded = df_cleaned_os.explode('OpSysProfessional use')
df_cleaned_os_sorted = df_cleaned_os_exploded['OpSysProfessional use'].value_counts().reset_index()
df_cleaned_os_sorted.columns = ['OpSysProfessional', 'Count']
df_cleaned_os_sorted = df_cleaned_os_sorted.sort_values(by='Count', ascending=False)
top_5_os = df_cleaned_os_sorted.head(5)

# %%
plt.figure(figsize=(8, 8))
plt.pie(top_5_os['Count'],labels=top_5_os['OpSysProfessional'], autopct='%1.1f%%')
plt.axis('equal')
plt.show()
