# %%
import pandas as pd
import json

# JSON data as a string
json_data ='''
[
    {"Country": "USA", "Population": 331, "GDP": 21.4, "HDI": 0.926},
    {"Country": "Canada", "Population": 38, "GDP": 1.8, "HDI": 0.929},
    {"Country": "Germany", "Population": 83, "GDP": 4.2, "HDI": 0.947}
]
''' # Keep with quote due to multile json
json_data = json.loads(json_data)
# Convert JSON to DataFrame
df = pd.DataFrame(json_data)

print(df)
# Out:
#    Country  Population   GDP    HDI
# 0      USA         331  21.4  0.926
# 1   Canada          38   1.8  0.929
# 2  Germany          83   4.2  0.947
